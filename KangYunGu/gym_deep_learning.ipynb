# %%
# %pip install torch
# Out:
# Collecting torch
#   Downloading torch-2.7.0-cp312-cp312-win_amd64.whl.metadata (29 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\play data\miniconda3\lib\site-packages (from torch) (4.12.2)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in c:\users\play data\miniconda3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\play data\miniconda3\lib\site-packages (from torch) (3.1.6)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: setuptools in c:\users\play data\miniconda3\lib\site-packages (from torch) (75.8.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\play data\miniconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.7.0-cp312-cp312-win_amd64.whl (212.5 MB)
#    ---------------------------------------- 0.0/212.5 MB ? eta -:--:--
#    - -------------------------------------- 9.2/212.5 MB 47.4 MB/s eta 0:00:05
#    --- ------------------------------------ 19.4/212.5 MB 48.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 25.2/212.5 MB 40.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 27.8/212.5 MB 35.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 31.7/212.5 MB 31.0 MB/s eta 0:00:06
#    ------ --------------------------------- 35.4/212.5 MB 28.5 MB/s eta 0:00:07
#    ------- -------------------------------- 41.4/212.5 MB 28.9 MB/s eta 0:00:06
#    --------- ------------------------------ 51.6/212.5 MB 31.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 60.8/212.5 MB 32.8 MB/s eta 0:00:05
#    ------------ --------------------------- 68.9/212.5 MB 33.6 MB/s eta 0:00:05
#    -------------- ------------------------- 75.2/212.5 MB 33.1 MB/s eta 0:00:05
#    --------------- ------------------------ 82.8/212.5 MB 33.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 89.1/212.5 MB 33.3 MB/s eta 0:00:04
#    ----------------- ---------------------- 93.8/212.5 MB 32.6 MB/s eta 0:00:04
#    ------------------ -------------------- 102.8/212.5 MB 33.3 MB/s eta 0:00:04
#    -------------------- ------------------ 109.6/212.5 MB 33.2 MB/s eta 0:00:04
#    --------------------- ----------------- 117.4/212.5 MB 33.6 MB/s eta 0:00:03
#    ---------------------- ---------------- 123.5/212.5 MB 33.4 MB/s eta 0:00:03
#    ------------------------ -------------- 130.8/212.5 MB 33.4 MB/s eta 0:00:03
#    ------------------------- ------------- 139.5/212.5 MB 33.9 MB/s eta 0:00:03
#    --------------------------- ----------- 148.4/212.5 MB 34.2 MB/s eta 0:00:02
#    ---------------------------- ---------- 154.7/212.5 MB 34.1 MB/s eta 0:00:02
#    ----------------------------- --------- 163.3/212.5 MB 34.4 MB/s eta 0:00:02
#    ------------------------------- ------- 170.9/212.5 MB 34.6 MB/s eta 0:00:02
#    -------------------------------- ------ 175.6/212.5 MB 34.1 MB/s eta 0:00:02
#    -------------------------------- ------ 178.8/212.5 MB 33.5 MB/s eta 0:00:02
#    --------------------------------- ----- 184.8/212.5 MB 33.2 MB/s eta 0:00:01
#    ----------------------------------- --- 191.1/212.5 MB 33.5 MB/s eta 0:00:01
#    ----------------------------------- --- 195.8/212.5 MB 32.8 MB/s eta 0:00:01
#    ------------------------------------- - 204.7/212.5 MB 33.1 MB/s eta 0:00:01
#    --------------------------------------  208.1/212.5 MB 32.6 MB/s eta 0:00:01
#    --------------------------------------  212.3/212.5 MB 32.5 MB/s eta 0:00:01
#    --------------------------------------  212.3/212.5 MB 32.5 MB/s eta 0:00:01
#    --------------------------------------- 212.5/212.5 MB 31.1 MB/s eta 0:00:00
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, fsspec, filelock, torch
# Successfully installed filelock-3.18.0 fsspec-2025.5.1 mpmath-1.3.0 sympy-1.14.0 torch-2.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, pickle
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
import torch.optim as optim
from sklearn.metrics import classification_report, roc_auc_score, precision_score, recall_score, f1_score, accuracy_score
from sklearn.preprocessing import StandardScaler, RobustScaler
import numpy as np
import pandas as pd


data = pd.read_csv("data/gym_churn.csv")


class DNN(nn.Module):
    def __init__(self, Cin):
        super().__init__()
        self.relu = nn.ReLU()

        self.dropout = nn.Dropout(0.4)
        self.linear1 = nn.Linear(Cin, 32)
        self.linear2 = nn.Linear(32, 128)
        self.linear3 = nn.Linear(128, 16)
        self.fc = nn.Linear(16, 1)

    def forward(self, x):
        out = self.linear1(x)
        out = self.relu(out)
        out = self.linear2(out)
        out = self.relu(out)
        out = self.linear3(out)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.fc(out)

        return out


# X = torch.tensor(data.drop('Churn', axis=1).to_numpy(), dtype=torch.float32) #(3200, 12)
X = data.drop('Churn', axis=1)
y = torch.tensor(data['Churn'].to_numpy(), dtype=torch.float32).unsqueeze(dim=1) #(3200, 1)

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, stratify=y, random_state=42)

# scaler = StandardScaler()
scaler = RobustScaler()
X_train_scaled = torch.tensor(scaler.fit_transform(X_train), dtype=torch.float32)
X_val_scaled =  torch.tensor(scaler.transform(X_val), dtype=torch.float32)

model = DNN(Cin = X_train_scaled.size(1))
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.AdamW(model.parameters(), lr = 0.001)#, weight_decay=1e-4)

model.train()
best_f1score=  0.
for epoch in range(1000):

  optimizer.zero_grad()
  y_pred = model(X_train_scaled).type(torch.float32)
  loss = criterion(y_pred, y_train)
  loss.backward()
  optimizer.step()

  if (epoch + 1) % 10 == 0:
    print(f'Epoch: {epoch + 1} Loss: {loss.item()}')

  if (epoch + 1) % 10 == 0:

    model.eval()
    with torch.no_grad():

      y_val_pred = model(X_val_scaled)
      loss = criterion(y_val_pred, y_val)

      y_val_prob = F.sigmoid(y_val_pred)
      y_val_pred_label = (y_val_prob >= 0.5).float()

      y_true = y_val.numpy()
      y_pred_labels = y_val_pred_label.numpy()

      acc = accuracy_score(y_true, y_pred_labels)
      precision = precision_score(y_true, y_pred_labels)
      recall = recall_score(y_true, y_pred_labels)
      f1 = f1_score(y_true, y_pred_labels)

      print(f'EVAL loss: {loss:.4f} Accuracy: {acc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}')

      if best_f1score < f1:
        torch.save(model.state_dict(), './best_model.pth')
        with open('DNN_scaler.pkl', 'wb') as f:
          pickle.dump(scaler, f)
        print(f'====Best model saved at {epoch+1} with F1 Score: {f1:.4f}')
        best_f1score = f1
# Out:
# Epoch: 10 Loss: 0.6599882245063782
# EVAL loss: 0.6495 Accuracy: 0.7550, Precision: 1.0000, Recall: 0.0755, F1 Score: 0.1404
# ====Best model saved at 10 with F1 Score: 0.1404
# Epoch: 20 Loss: 0.5691842436790466
# EVAL loss: 0.5530 Accuracy: 0.7350, Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch: 30 Loss: 0.4664098620414734
# EVAL loss: 0.4507 Accuracy: 0.7350, Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch: 40 Loss: 0.39309462904930115
# EVAL loss: 0.3814 Accuracy: 0.7700, Precision: 0.9667, Recall: 0.1368, F1 Score: 0.2397
# ====Best model saved at 40 with F1 Score: 0.2397
# Epoch: 50 Loss: 0.3289259374141693
# EVAL loss: 0.3211 Accuracy: 0.8775, Precision: 0.9385, Recall: 0.5755, F1 Score: 0.7135
# ====Best model saved at 50 with F1 Score: 0.7135
# Epoch: 60 Loss: 0.2864466905593872
# EVAL loss: 0.2837 Accuracy: 0.9087, Precision: 0.8840, Recall: 0.7547, F1 Score: 0.8142
# ====Best model saved at 60 with F1 Score: 0.8142
# C:\Users\play data\miniconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\play data\miniconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch: 70 Loss: 0.25237706303596497
# EVAL loss: 0.2535 Accuracy: 0.9087, Precision: 0.8424, Recall: 0.8066, F1 Score: 0.8241
# ====Best model saved at 70 with F1 Score: 0.8241
# Epoch: 80 Loss: 0.22464916110038757
# EVAL loss: 0.2267 Accuracy: 0.9150, Precision: 0.8429, Recall: 0.8349, F1 Score: 0.8389
# ====Best model saved at 80 with F1 Score: 0.8389
# Epoch: 90 Loss: 0.20406000316143036
# EVAL loss: 0.2062 Accuracy: 0.9200, Precision: 0.8558, Recall: 0.8396, F1 Score: 0.8476
# ====Best model saved at 90 with F1 Score: 0.8476
# Epoch: 100 Loss: 0.18962350487709045
# EVAL loss: 0.1935 Accuracy: 0.9275, Precision: 0.8667, Recall: 0.8585, F1 Score: 0.8626
# ====Best model saved at 100 with F1 Score: 0.8626
# Epoch: 110 Loss: 0.18031135201454163
# EVAL loss: 0.1868 Accuracy: 0.9325, Precision: 0.8798, Recall: 0.8632, F1 Score: 0.8714
# ====Best model saved at 110 with F1 Score: 0.8714
# Epoch: 120 Loss: 0.17353500425815582
# EVAL loss: 0.1828 Accuracy: 0.9275, Precision: 0.8738, Recall: 0.8491, F1 Score: 0.8612
# Epoch: 130 Loss: 0.16777990758419037
# EVAL loss: 0.1782 Accuracy: 0.9300, Precision: 0.8750, Recall: 0.8585, F1 Score: 0.8667
# Epoch: 140 Loss: 0.1629542112350464
# EVAL loss: 0.1741 Accuracy: 0.9287, Precision: 0.8708, Recall: 0.8585, F1 Score: 0.8646
# Epoch: 150 Loss: 0.15890184044837952
# EVAL loss: 0.1709 Accuracy: 0.9287, Precision: 0.8708, Recall: 0.8585, F1 Score: 0.8646
# Epoch: 160 Loss: 0.155434250831604
# EVAL loss: 0.1684 Accuracy: 0.9325, Precision: 0.8762, Recall: 0.8679, F1 Score: 0.8720
# ====Best model saved at 160 with F1 Score: 0.8720
# Epoch: 170 Loss: 0.15255272388458252
# EVAL loss: 0.1669 Accuracy: 0.9313, Precision: 0.8756, Recall: 0.8632, F1 Score: 0.8694
# Epoch: 180 Loss: 0.1499795764684677
# EVAL loss: 0.1655 Accuracy: 0.9313, Precision: 0.8756, Recall: 0.8632, F1 Score: 0.8694
# Epoch: 190 Loss: 0.14746609330177307
# EVAL loss: 0.1644 Accuracy: 0.9325, Precision: 0.8798, Recall: 0.8632, F1 Score: 0.8714
# Epoch: 200 Loss: 0.14504501223564148
# EVAL loss: 0.1630 Accuracy: 0.9337, Precision: 0.8841, Recall: 0.8632, F1 Score: 0.8735
# ====Best model saved at 200 with F1 Score: 0.8735
# Epoch: 210 Loss: 0.1424979269504547
# EVAL loss: 0.1620 Accuracy: 0.9363, Precision: 0.8852, Recall: 0.8726, F1 Score: 0.8789
# ====Best model saved at 210 with F1 Score: 0.8789
# Epoch: 220 Loss: 0.13995294272899628
# EVAL loss: 0.1610 Accuracy: 0.9387, Precision: 0.8937, Recall: 0.8726, F1 Score: 0.8831
# ====Best model saved at 220 with F1 Score: 0.8831
# Epoch: 230 Loss: 0.13732466101646423
# EVAL loss: 0.1592 Accuracy: 0.9375, Precision: 0.8894, Recall: 0.8726, F1 Score: 0.8810
# Epoch: 240 Loss: 0.1344536542892456
# EVAL loss: 0.1576 Accuracy: 0.9413, Precision: 0.8986, Recall: 0.8774, F1 Score: 0.8878
# ====Best model saved at 240 with F1 Score: 0.8878
# Epoch: 250 Loss: 0.1315573751926422
# EVAL loss: 0.1570 Accuracy: 0.9400, Precision: 0.8942, Recall: 0.8774, F1 Score: 0.8857
# Epoch: 260 Loss: 0.1282774955034256
# EVAL loss: 0.1564 Accuracy: 0.9400, Precision: 0.8942, Recall: 0.8774, F1 Score: 0.8857
# Epoch: 270 Loss: 0.12449393421411514
# EVAL loss: 0.1563 Accuracy: 0.9413, Precision: 0.8947, Recall: 0.8821, F1 Score: 0.8884
# ====Best model saved at 270 with F1 Score: 0.8884
# Epoch: 280 Loss: 0.12065118551254272
# EVAL loss: 0.1548 Accuracy: 0.9425, Precision: 0.8952, Recall: 0.8868, F1 Score: 0.8910
# ====Best model saved at 280 with F1 Score: 0.8910
# Epoch: 290 Loss: 0.11709703505039215
# EVAL loss: 0.1548 Accuracy: 0.9425, Precision: 0.8952, Recall: 0.8868, F1 Score: 0.8910
# Epoch: 300 Loss: 0.11351712048053741
# EVAL loss: 0.1542 Accuracy: 0.9450, Precision: 0.9000, Recall: 0.8915, F1 Score: 0.8957
# ====Best model saved at 300 with F1 Score: 0.8957
# Epoch: 310 Loss: 0.10996150970458984
# EVAL loss: 0.1537 Accuracy: 0.9437, Precision: 0.8957, Recall: 0.8915, F1 Score: 0.8936
# Epoch: 320 Loss: 0.10641948878765106
# EVAL loss: 0.1535 Accuracy: 0.9463, Precision: 0.9005, Recall: 0.8962, F1 Score: 0.8983
# ====Best model saved at 320 with F1 Score: 0.8983
# Epoch: 330 Loss: 0.10283127427101135
# EVAL loss: 0.1533 Accuracy: 0.9450, Precision: 0.9000, Recall: 0.8915, F1 Score: 0.8957
# Epoch: 340 Loss: 0.09930781275033951
# EVAL loss: 0.1530 Accuracy: 0.9463, Precision: 0.9043, Recall: 0.8915, F1 Score: 0.8979
# Epoch: 350 Loss: 0.09596800059080124
# EVAL loss: 0.1523 Accuracy: 0.9513, Precision: 0.9139, Recall: 0.9009, F1 Score: 0.9074
# ====Best model saved at 350 with F1 Score: 0.9074
# Epoch: 360 Loss: 0.09268283098936081
# EVAL loss: 0.1519 Accuracy: 0.9500, Precision: 0.9135, Recall: 0.8962, F1 Score: 0.9048
# Epoch: 370 Loss: 0.08941435068845749
# EVAL loss: 0.1513 Accuracy: 0.9500, Precision: 0.9135, Recall: 0.8962, F1 Score: 0.9048
# Epoch: 380 Loss: 0.08614373952150345
# EVAL loss: 0.1516 Accuracy: 0.9513, Precision: 0.9139, Recall: 0.9009, F1 Score: 0.9074
# Epoch: 390 Loss: 0.08277704566717148
# EVAL loss: 0.1511 Accuracy: 0.9525, Precision: 0.9143, Recall: 0.9057, F1 Score: 0.9100
# ====Best model saved at 390 with F1 Score: 0.9100
# Epoch: 400 Loss: 0.07945617288351059
# EVAL loss: 0.1517 Accuracy: 0.9537, Precision: 0.9147, Recall: 0.9104, F1 Score: 0.9125
# ====Best model saved at 400 with F1 Score: 0.9125
# Epoch: 410 Loss: 0.07621120661497116
# EVAL loss: 0.1518 Accuracy: 0.9525, Precision: 0.9183, Recall: 0.9009, F1 Score: 0.9095
# Epoch: 420 Loss: 0.07324535399675369
# EVAL loss: 0.1526 Accuracy: 0.9500, Precision: 0.9095, Recall: 0.9009, F1 Score: 0.9052
# Epoch: 430 Loss: 0.07027063518762589
# EVAL loss: 0.1524 Accuracy: 0.9513, Precision: 0.9179, Recall: 0.8962, F1 Score: 0.9069
# Epoch: 440 Loss: 0.06760028004646301
# EVAL loss: 0.1531 Accuracy: 0.9500, Precision: 0.9135, Recall: 0.8962, F1 Score: 0.9048
# Epoch: 450 Loss: 0.06504303216934204
# EVAL loss: 0.1545 Accuracy: 0.9487, Precision: 0.9130, Recall: 0.8915, F1 Score: 0.9021
# Epoch: 460 Loss: 0.06249742582440376
# EVAL loss: 0.1559 Accuracy: 0.9475, Precision: 0.9087, Recall: 0.8915, F1 Score: 0.9000
# Epoch: 470 Loss: 0.06015125289559364
# EVAL loss: 0.1566 Accuracy: 0.9475, Precision: 0.9087, Recall: 0.8915, F1 Score: 0.9000
# Epoch: 480 Loss: 0.05796650052070618
# EVAL loss: 0.1596 Accuracy: 0.9475, Precision: 0.9087, Recall: 0.8915, F1 Score: 0.9000
# Epoch: 490 Loss: 0.055852681398391724
# EVAL loss: 0.1622 Accuracy: 0.9475, Precision: 0.9087, Recall: 0.8915, F1 Score: 0.9000
# Epoch: 500 Loss: 0.053929075598716736
# EVAL loss: 0.1645 Accuracy: 0.9475, Precision: 0.9087, Recall: 0.8915, F1 Score: 0.9000
# Epoch: 510 Loss: 0.05205681174993515
# EVAL loss: 0.1668 Accuracy: 0.9475, Precision: 0.9087, Recall: 0.8915, F1 Score: 0.9000
# Epoch: 520 Loss: 0.05039167404174805
# EVAL loss: 0.1692 Accuracy: 0.9463, Precision: 0.9043, Recall: 0.8915, F1 Score: 0.8979
# Epoch: 530 Loss: 0.04893464222550392
# EVAL loss: 0.1719 Accuracy: 0.9475, Precision: 0.9048, Recall: 0.8962, F1 Score: 0.9005
# Epoch: 540 Loss: 0.047647345811128616
# EVAL loss: 0.1740 Accuracy: 0.9475, Precision: 0.9048, Recall: 0.8962, F1 Score: 0.9005
# Epoch: 550 Loss: 0.04597798362374306
# EVAL loss: 0.1770 Accuracy: 0.9475, Precision: 0.9048, Recall: 0.8962, F1 Score: 0.9005
# Epoch: 560 Loss: 0.04472556710243225
# EVAL loss: 0.1810 Accuracy: 0.9475, Precision: 0.9048, Recall: 0.8962, F1 Score: 0.9005
# Epoch: 570 Loss: 0.043339695781469345
# EVAL loss: 0.1833 Accuracy: 0.9463, Precision: 0.9043, Recall: 0.8915, F1 Score: 0.8979
# Epoch: 580 Loss: 0.04210197925567627
# EVAL loss: 0.1870 Accuracy: 0.9475, Precision: 0.9048, Recall: 0.8962, F1 Score: 0.9005
# Epoch: 590 Loss: 0.04096166044473648
# EVAL loss: 0.1903 Accuracy: 0.9475, Precision: 0.9048, Recall: 0.8962, F1 Score: 0.9005
# Epoch: 600 Loss: 0.039684101939201355
# EVAL loss: 0.1933 Accuracy: 0.9475, Precision: 0.9048, Recall: 0.8962, F1 Score: 0.9005
# Epoch: 610 Loss: 0.03884729743003845
# EVAL loss: 0.1965 Accuracy: 0.9475, Precision: 0.9048, Recall: 0.8962, F1 Score: 0.9005
# Epoch: 620 Loss: 0.03776116669178009
# EVAL loss: 0.2003 Accuracy: 0.9475, Precision: 0.9048, Recall: 0.8962, F1 Score: 0.9005
# Epoch: 630 Loss: 0.036513518542051315
# EVAL loss: 0.2026 Accuracy: 0.9487, Precision: 0.9052, Recall: 0.9009, F1 Score: 0.9031
# Epoch: 640 Loss: 0.035382241010665894
# EVAL loss: 0.2056 Accuracy: 0.9487, Precision: 0.9052, Recall: 0.9009, F1 Score: 0.9031
# Epoch: 650 Loss: 0.034348729997873306
# EVAL loss: 0.2077 Accuracy: 0.9500, Precision: 0.9095, Recall: 0.9009, F1 Score: 0.9052
# Epoch: 660 Loss: 0.033307239413261414
# EVAL loss: 0.2113 Accuracy: 0.9475, Precision: 0.9009, Recall: 0.9009, F1 Score: 0.9009
# Epoch: 670 Loss: 0.032412197440862656
# EVAL loss: 0.2135 Accuracy: 0.9513, Precision: 0.9139, Recall: 0.9009, F1 Score: 0.9074
# Epoch: 680 Loss: 0.03130796551704407
# EVAL loss: 0.2176 Accuracy: 0.9475, Precision: 0.9009, Recall: 0.9009, F1 Score: 0.9009
# Epoch: 690 Loss: 0.030437331646680832
# EVAL loss: 0.2219 Accuracy: 0.9475, Precision: 0.9009, Recall: 0.9009, F1 Score: 0.9009
# Epoch: 700 Loss: 0.029593264684081078
# EVAL loss: 0.2237 Accuracy: 0.9487, Precision: 0.9052, Recall: 0.9009, F1 Score: 0.9031
# Epoch: 710 Loss: 0.02861509844660759
# EVAL loss: 0.2285 Accuracy: 0.9475, Precision: 0.9009, Recall: 0.9009, F1 Score: 0.9009
# Epoch: 720 Loss: 0.0279577374458313
# EVAL loss: 0.2330 Accuracy: 0.9463, Precision: 0.8967, Recall: 0.9009, F1 Score: 0.8988
# Epoch: 730 Loss: 0.027046332135796547
# EVAL loss: 0.2332 Accuracy: 0.9475, Precision: 0.9009, Recall: 0.9009, F1 Score: 0.9009
# Epoch: 740 Loss: 0.02612760290503502
# EVAL loss: 0.2373 Accuracy: 0.9463, Precision: 0.8967, Recall: 0.9009, F1 Score: 0.8988
# Epoch: 750 Loss: 0.02528921328485012
# EVAL loss: 0.2395 Accuracy: 0.9475, Precision: 0.9009, Recall: 0.9009, F1 Score: 0.9009
# Epoch: 760 Loss: 0.024462759494781494
# EVAL loss: 0.2433 Accuracy: 0.9463, Precision: 0.8967, Recall: 0.9009, F1 Score: 0.8988
# Epoch: 770 Loss: 0.023968413472175598
# EVAL loss: 0.2480 Accuracy: 0.9450, Precision: 0.8925, Recall: 0.9009, F1 Score: 0.8967
# Epoch: 780 Loss: 0.023028550669550896
# EVAL loss: 0.2497 Accuracy: 0.9450, Precision: 0.8962, Recall: 0.8962, F1 Score: 0.8962
# Epoch: 790 Loss: 0.02240138128399849
# EVAL loss: 0.2541 Accuracy: 0.9437, Precision: 0.8920, Recall: 0.8962, F1 Score: 0.8941
# Epoch: 800 Loss: 0.02158569172024727
# EVAL loss: 0.2558 Accuracy: 0.9450, Precision: 0.8962, Recall: 0.8962, F1 Score: 0.8962
# Epoch: 810 Loss: 0.020865565165877342
# EVAL loss: 0.2592 Accuracy: 0.9463, Precision: 0.8967, Recall: 0.9009, F1 Score: 0.8988
# Epoch: 820 Loss: 0.020216919481754303
# EVAL loss: 0.2620 Accuracy: 0.9463, Precision: 0.8967, Recall: 0.9009, F1 Score: 0.8988
# Epoch: 830 Loss: 0.019574269652366638
# EVAL loss: 0.2663 Accuracy: 0.9463, Precision: 0.8967, Recall: 0.9009, F1 Score: 0.8988
# Epoch: 840 Loss: 0.018941646441817284
# EVAL loss: 0.2683 Accuracy: 0.9450, Precision: 0.8962, Recall: 0.8962, F1 Score: 0.8962
# Epoch: 850 Loss: 0.018313312903046608
# EVAL loss: 0.2726 Accuracy: 0.9463, Precision: 0.8967, Recall: 0.9009, F1 Score: 0.8988
# Epoch: 860 Loss: 0.017717385664582253
# EVAL loss: 0.2755 Accuracy: 0.9450, Precision: 0.8962, Recall: 0.8962, F1 Score: 0.8962
# Epoch: 870 Loss: 0.017144260928034782
# EVAL loss: 0.2787 Accuracy: 0.9463, Precision: 0.8967, Recall: 0.9009, F1 Score: 0.8988
# Epoch: 880 Loss: 0.016595670953392982
# EVAL loss: 0.2809 Accuracy: 0.9437, Precision: 0.8957, Recall: 0.8915, F1 Score: 0.8936
# Epoch: 890 Loss: 0.01607472263276577
# EVAL loss: 0.2855 Accuracy: 0.9450, Precision: 0.8962, Recall: 0.8962, F1 Score: 0.8962
# Epoch: 900 Loss: 0.01557944156229496
# EVAL loss: 0.2871 Accuracy: 0.9437, Precision: 0.8957, Recall: 0.8915, F1 Score: 0.8936
# Epoch: 910 Loss: 0.015044910833239555
# EVAL loss: 0.2921 Accuracy: 0.9450, Precision: 0.8962, Recall: 0.8962, F1 Score: 0.8962
# Epoch: 920 Loss: 0.01455594040453434
# EVAL loss: 0.2951 Accuracy: 0.9450, Precision: 0.8962, Recall: 0.8962, F1 Score: 0.8962
# Epoch: 930 Loss: 0.01412375457584858
# EVAL loss: 0.2994 Accuracy: 0.9450, Precision: 0.8962, Recall: 0.8962, F1 Score: 0.8962
# Epoch: 940 Loss: 0.013631251640617847
# EVAL loss: 0.3009 Accuracy: 0.9450, Precision: 0.8962, Recall: 0.8962, F1 Score: 0.8962
# Epoch: 950 Loss: 0.01314473431557417
# EVAL loss: 0.3057 Accuracy: 0.9463, Precision: 0.8967, Recall: 0.9009, F1 Score: 0.8988
# Epoch: 960 Loss: 0.01270299218595028
# EVAL loss: 0.3096 Accuracy: 0.9463, Precision: 0.8967, Recall: 0.9009, F1 Score: 0.8988
# Epoch: 970 Loss: 0.012315286323428154
# EVAL loss: 0.3120 Accuracy: 0.9437, Precision: 0.8957, Recall: 0.8915, F1 Score: 0.8936
# Epoch: 980 Loss: 0.01189203280955553
# EVAL loss: 0.3184 Accuracy: 0.9450, Precision: 0.8925, Recall: 0.9009, F1 Score: 0.8967
# Epoch: 990 Loss: 0.011425801552832127
# EVAL loss: 0.3199 Accuracy: 0.9463, Precision: 0.8967, Recall: 0.9009, F1 Score: 0.8988
# Epoch: 1000 Loss: 0.011023346334695816
# EVAL loss: 0.3237 Accuracy: 0.9463, Precision: 0.8967, Recall: 0.9009, F1 Score: 0.8988
